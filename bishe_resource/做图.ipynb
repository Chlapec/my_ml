# %%
import numpy as np

# %%
loss = np.load("./loss.npy")

# %%
loss[0]
# Out:
# array([ 0.89676732,  0.55569056,  0.45826656,  0.41754471,  0.33647694,
#         0.33448184,  0.3019201 ,  0.27787237,  0.24638423,  0.21632413,
#         0.19876287,  0.18772125,  0.15931946,  0.16022523,  0.1426433 ,
#         0.14767933,  0.14864981,  0.14238069,  0.10103725,  0.10428396,
#         0.1017931 ,  0.098739  ,  0.10168861,  0.09471944,  0.06939856,
#         0.07028816,  0.0705715 ,  0.0759604 ,  0.05975031,  0.07105757,
#         0.07359705,  0.06385288,  0.05513181,  0.05466225,  0.05258015,
#         0.06841187,  0.04461047,  0.05266351,  0.05766573,  0.03682485,
#         0.03943868,  0.06818816,  0.0436481 ,  0.04492767,  0.0366632 ,
#         0.04868807,  0.03492521,  0.04279632,  0.03851495,  0.04713905,
#         0.04095501,  0.0332727 ,  0.02888471,  0.0444719 ,  0.02829863,
#         0.03182399,  0.02980721,  0.02406621,  0.04205522,  0.03895383,
#         0.02638351,  0.01922776,  0.03392539,  0.04184215,  0.0259633 ,
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# 设置画布大小
plt.figure(figsize=(22, 18))
# 设置刻度字体大小
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
ax = plt.subplot(221)

plt.plot(loss[0])
plt.title('rpn-cls-loss', fontsize=20)
ax.set_ylabel('rpn-cls-loss', fontsize=20)
ax.set_xlabel('Epochs', fontsize=20)

# 设置刻度字体大小
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
ax = plt.subplot(222)

plt.plot(loss[1])
plt.title('rpn_regr-loss', fontsize=20)
ax.set_ylabel('rpn_regr-loss', fontsize=20)
ax.set_xlabel('Epochs', fontsize=20)

# 设置刻度字体大小
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
ax = plt.subplot(223)

plt.plot(loss[2])
plt.title('class_cls-loss', fontsize=20)
ax.set_ylabel('class_cls-loss', fontsize=20)
ax.set_xlabel('Epochs', fontsize=20)
              
# 设置刻度字体大小
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
ax = plt.subplot(224)

plt.plot(loss[3])
plt.title('class_regr-loss', fontsize=20)
ax.set_ylabel('class_regr-loss', fontsize=20)
ax.set_xlabel('Epochs', fontsize=20)

# %%
# 设置画布大小
plt.figure(figsize=(12, 10))
# 设置刻度字体大小
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
ax = plt.subplot(111)

plt.plot(loss[1])
plt.title('rpn-cls-loss', fontsize=20)
ax.set_ylabel('rpn-cls-loss', fontsize=20)
ax.set_xlabel('Epochs', fontsize=20)
